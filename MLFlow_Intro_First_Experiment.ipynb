# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv('./collegePlace.csv')
data = pd.DataFrame(data)
data.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# 3                  1            1
# 4                  0            1

# %%
data.shape
# Out:
# (2966, 8)

# %%
data.isna().sum()
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# Hostel               0
# HistoryOfBacklogs    0
# PlacedOrNot          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
for i in data.select_dtypes(include="object").columns:
    data[i] = label.fit_transform(data[i])

# %%
data
# Out:
#       Age  Gender  Stream  Internships  CGPA  Hostel  HistoryOfBacklogs  \
# 0      22       0       0            1     8       1                  1
# 1      21       0       0            0     7       1                  1
# 2      22       0       0            1     6       0                  0
# 3      21       0       0            0     8       0                  1
# 4      22       0       0            0     8       1                  0
# ...   ...     ...     ...          ...   ...     ...                ...
# 2961   23       0       0            0     7       0                  0
# 2962   23       0       0            1     7       1                  0
# 2963   22       0       0            1     7       0                  0
# 2964   22       0       0            1     7       0                  0
# 2965   23       0       0            0     8       0                  0
#
#       PlacedOrNot
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 2961            0
# 2962            0
# 2963            0
# 2964            0
# 2965            1
#
# [2966 rows x 8 columns]

# %%
X = data.iloc[:,:-1]

# %%
X
# Out:
#       Age  Gender  Stream  Internships  CGPA  Hostel  HistoryOfBacklogs
# 0      22       0       0            1     8       1                  1
# 1      21       0       0            0     7       1                  1
# 2      22       0       0            1     6       0                  0
# 3      21       0       0            0     8       0                  1
# 4      22       0       0            0     8       1                  0
# ...   ...     ...     ...          ...   ...     ...                ...
# 2961   23       0       0            0     7       0                  0
# 2962   23       0       0            1     7       1                  0
# 2963   22       0       0            1     7       0                  0
# 2964   22       0       0            1     7       0                  0
# 2965   23       0       0            0     8       0                  0
#
# [2966 rows x 7 columns]

# %%
y = data.iloc[:,-1]

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2961    0
# 2962    0
# 2963    0
# 2964    0
# 2965    1
# Name: PlacedOrNot, Length: 2966, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(X , y , test_size= 0.3 , random_state= 42)

# %%
x_train.shape
# Out:
# (2076, 7)

# %%
y_train.shape
# Out:
# (2076,)

# %%
params = {
    "max_depth" : 5,
    "random_state" : 40 ,
    "criterion" :'gini',

}

# %%
model = DecisionTreeClassifier(**params)

# %%
model.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=40)

# %%
model.score(x_train , y_train)*100 , model.score(x_test , y_test )*100
# Out:
# (88.10211946050096, 88.08988764044943)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_pred , y_test)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88       490
#            1       0.80      0.98      0.88       400
#
#     accuracy                           0.88       890
#    macro avg       0.89      0.89      0.88       890
# weighted avg       0.90      0.88      0.88       890

# %%
report_dict = classification_report( y_test , y_pred,  output_dict=True)

# %%
# !pip install mlflow

# %%
report_dict
# Out:
# {'0': {'precision': 0.7979591836734694,
#   'recall': 0.9824120603015075,
#   'f1-score': 0.8806306306306306,
#   'support': 398.0},
#  '1': {'precision': 0.9825,
#   'recall': 0.7987804878048781,
#   'f1-score': 0.8811659192825112,
#   'support': 492.0},
#  'accuracy': 0.8808988764044944,
#  'macro avg': {'precision': 0.8902295918367347,
#   'recall': 0.8905962740531927,
#   'f1-score': 0.8808982749565709,
#   'support': 890.0},
#  'weighted avg': {'precision': 0.8999750057326302,
#   'recall': 0.8808988764044944,
#   'f1-score': 0.8809265430089736,
#   'support': 890.0}}

# %%
# report['precision    ']

# %%
import mlflow

mlflow.set_experiment("Firsttt Experiment")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")


with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics(
        {
            "Accuracy" : report_dict['accuracy'],
            "Precision" : report_dict['0']['precision']
        })
    mlflow.sklearn.log_model(model , "Decision Tree")
# Out:
# 2025/06/24 16:40:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run nervous-auk-396 at: http://127.0.0.1:5000/#/experiments/727338492231251034/runs/bcec57ee862b4597bd4b9d276b1a087b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/727338492231251034
